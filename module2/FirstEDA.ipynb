# %%
import pandas as pd
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
data = pd.read_csv(url)
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# EDA imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")

# %%
# Basic summary and missing values
print('Shape:', data.shape)
print('\nSummary statistics:')
display(data.describe(include='all'))
print('\nMissing values:')
print(data.isnull().sum())
# Out:
# Shape: (891, 12)
#
# Summary statistics:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
data["Cabin"]
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
data["Cabin"] = data["Cabin"].fillna("Unknown")
data["Cabin"]
# Out:
# 0      Unknown
# 1          C85
# 2      Unknown
# 3         C123
# 4      Unknown
#         ...
# 886    Unknown
# 887        B42
# 888    Unknown
# 889       C148
# 890    Unknown
# Name: Cabin, Length: 891, dtype: object

# %%
data["Embarked"] = data["Embarked"].fillna(data["Embarked"].mode()[0])
data["Embarked"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
data["Age"] = data["Age"].fillna(data["Age"].median())
print(data.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data["Survived"] = data["Survived"].replace(0,"No")
data["Survived"] = data["Survived"].replace(1,"Yes")
data["Survived"]
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3      Yes
# 4       No
#       ...
# 886     No
# 887    Yes
# 888     No
# 889    Yes
# 890     No
# Name: Survived, Length: 891, dtype: object

# %%
# Plots: counts, age distribution by survival, fare by class, correlation heatmap
plt.figure(figsize=(6,4))
sns.countplot(x='Survived', data=data, palette='Set2')
plt.title('Survival counts')
#plt.xlabel('Yes (1) / No (0)')
plt.show()

plt.figure(figsize=(8,6))
sns.histplot(data=data, x='Age', hue='Survived', kde=True, multiple='dodge', palette='Set1')
plt.title('Age distribution by Survival')
plt.show()

plt.figure(figsize=(8,6))
sns.boxplot(x='Pclass', y='Fare', hue='Survived', data=data, palette='Set3')
plt.title('Fare by Pclass and Survival')
plt.show()

plt.figure(figsize=(10,8))
corr = data.select_dtypes(include=[np.number]).corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Numeric feature correlations')
plt.show()
# Out:
# /var/folders/c_/hqy2nvfs4ls5mz42kt48b06h0000gn/T/ipykernel_66282/469750548.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=data, palette='Set2')
